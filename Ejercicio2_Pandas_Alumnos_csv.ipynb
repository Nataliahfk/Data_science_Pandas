# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliahfk/Data_science_Pandas/blob/main/Ejercicio2_Pandas_Alumnos_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Ejercicio 1**

# %% [markdown]
# ####Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.

# %%
import pandas as pd # importar en pandas
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
df_alumnos = pd.read_csv(url)# leer y almacenar en un DataFrame
df_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
df_alumnos.shape
# Out:
# (18, 4)

# %% [markdown]
# ####Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.**

# %%
# suma los datos nulos
df_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
# Reemplazar los datos nulos por valor 0
df_alumnos.fillna(0, inplace=True)

# %%
df_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %% [markdown]
# ####Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
# Guardamos los índices de las filas a eliminar en una variable
df_alumnos_eliminados = df_alumnos.query('Nombre == "Alicia" | Nombre == "Carlos"').index

# Eliminamos las filas correspondientes a los estudiantes "Alicia" y "Carlos"
df_alumnos.drop(df_alumnos_eliminados, inplace=True)
df_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   0.0    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
df_alumnos.shape # elimino 2 registros
# Out:
# (16, 4)

# %% [markdown]
# ####Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
df_filtro = df_alumnos.query('Aprobado == "True"')
df_filtro
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   7.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   7.0     True

# %%
df_filtro.shape
# Out:
# (6, 4)

# %%
df_alumnos_apobados = df_filtro.copy()
df_alumnos_apobados
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   7.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   7.0     True

# %% [markdown]
# ####Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

# %%
df_alumnos_apobados.to_csv('alumnos_aprobados.csv',index=False)

# %%
pd.read_csv('alumnos_aprobados.csv')
# Out:
#      Nombre  Edad  Nota  Aprobado
# 0   Alberto    20   7.5      True
# 1     Brian    21  10.0      True
# 2   Daniela    21   7.0      True
# 3  Stephany    26  10.0      True
# 4    Miriam    25   9.0      True
# 5    Milena    29   7.0      True

# %% [markdown]
# ####Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.

# %%
df_alumnos_apobados['Nota'] = df_alumnos_apobados['Nota'].replace(7.0, 8.0)
df_alumnos_apobados
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   8.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   8.0     True

# %% [markdown]
# ##**Ejercicio2**

# %% [markdown]
# ####Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
df_alumnos['Puntos_extras'] = df_alumnos['Nota'] * 0.4
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras
# 0    Alberto    20   7.5       True            3.0
# 1        Ana    18   0.0      False            0.0
# 2     Camila    27   2.5      False            1.0
# 3      David    18   5.0      False            2.0
# 4      Brian    21  10.0       True            4.0
# 5      Bruna    23   0.0      False            0.0
# 6    Daniela    21   7.0       True            2.8
# 9     Victor    28   0.0      False            0.0
# 10    Danilo    21   0.0      False            0.0
# 11   Ignacio    24   4.5      False            1.8
# 12  Stephany    26  10.0       True            4.0
# 13    Miriam    25   9.0       True            3.6
# 14     Pablo    37   0.0      False            0.0
# 15    Milena    29   7.0       True            2.8
# 16     Lucas    33   0.0      False            0.0
# 17     Nadia    34   8.0  Verdadero            3.2

# %%
# Otra forma
df_alumnos['Puntos_extras'] = df_alumnos['Nota'].apply(lambda x: x*0.4)
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras
# 0    Alberto    20   7.5       True            3.0
# 1        Ana    18   0.0      False            0.0
# 2     Camila    27   2.5      False            1.0
# 3      David    18   5.0      False            2.0
# 4      Brian    21  10.0       True            4.0
# 5      Bruna    23   0.0      False            0.0
# 6    Daniela    21   7.0       True            2.8
# 9     Victor    28   0.0      False            0.0
# 10    Danilo    21   0.0      False            0.0
# 11   Ignacio    24   4.5      False            1.8
# 12  Stephany    26  10.0       True            4.0
# 13    Miriam    25   9.0       True            3.6
# 14     Pablo    37   0.0      False            0.0
# 15    Milena    29   7.0       True            2.8
# 16     Lucas    33   0.0      False            0.0
# 17     Nadia    34   8.0  Verdadero            3.2

# %% [markdown]
# ####Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.

# %%
df_alumnos['Notas_finales']= df_alumnos['Nota'] + df_alumnos['Puntos_extras']
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales
# 0    Alberto    20   7.5       True            3.0           10.5
# 1        Ana    18   0.0      False            0.0            0.0
# 2     Camila    27   2.5      False            1.0            3.5
# 3      David    18   5.0      False            2.0            7.0
# 4      Brian    21  10.0       True            4.0           14.0
# 5      Bruna    23   0.0      False            0.0            0.0
# 6    Daniela    21   7.0       True            2.8            9.8
# 9     Victor    28   0.0      False            0.0            0.0
# 10    Danilo    21   0.0      False            0.0            0.0
# 11   Ignacio    24   4.5      False            1.8            6.3
# 12  Stephany    26  10.0       True            4.0           14.0
# 13    Miriam    25   9.0       True            3.6           12.6
# 14     Pablo    37   0.0      False            0.0            0.0
# 15    Milena    29   7.0       True            2.8            9.8
# 16     Lucas    33   0.0      False            0.0            0.0
# 17     Nadia    34   8.0  Verdadero            3.2           11.2

# %% [markdown]
# ####Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# - True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# - False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

# %%
df_alumnos['Aprobado_final'] = df_alumnos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)
df_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5       True            3.0           10.5
# 1        Ana    18   0.0      False            0.0            0.0
# 2     Camila    27   2.5      False            1.0            3.5
# 3      David    18   5.0      False            2.0            7.0
# 4      Brian    21  10.0       True            4.0           14.0
# 5      Bruna    23   0.0      False            0.0            0.0
# 6    Daniela    21   7.0       True            2.8            9.8
# 9     Victor    28   0.0      False            0.0            0.0
# 10    Danilo    21   0.0      False            0.0            0.0
# 11   Ignacio    24   4.5      False            1.8            6.3
# 12  Stephany    26  10.0       True            4.0           14.0
# 13    Miriam    25   9.0       True            3.6           12.6
# 14     Pablo    37   0.0      False            0.0            0.0
# 15    Milena    29   7.0       True            2.8            9.8
# 16     Lucas    33   0.0      False            0.0            0.0
# 17     Nadia    34   8.0  Verdadero            3.2           11.2
#
#     Aprobado_final
# 0             True
# 1            False
# 2            False
# 3             True
# 4             True
# 5            False
# 6             True
# 9            False
# 10           False
# 11           False
# 12            True
# 13            True
# 14           False
# 15            True
# 16           False
# 17            True

# %%
df_alumnos.query('Aprobado_final == True')
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5       True            3.0           10.5
# 3      David    18   5.0      False            2.0            7.0
# 4      Brian    21  10.0       True            4.0           14.0
# 6    Daniela    21   7.0       True            2.8            9.8
# 12  Stephany    26  10.0       True            4.0           14.0
# 13    Miriam    25   9.0       True            3.6           12.6
# 15    Milena    29   7.0       True            2.8            9.8
# 17     Nadia    34   8.0  Verdadero            3.2           11.2
#
#     Aprobado_final
# 0             True
# 3             True
# 4             True
# 6             True
# 12            True
# 13            True
# 15            True
# 17            True

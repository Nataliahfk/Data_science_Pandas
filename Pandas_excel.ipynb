# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliahfk/Data_science_Pandas/blob/main/Pandas_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Aula 2 - Leyendo archivos Excel**

# %% [markdown]
# ###**Importando archivos Excel**

# %%
import pandas as pd

# %%
# Para que corran todos los códigos debo cargar cada vez el archivo excel
archivo = 'emisiones_CO2.xlsx'

# %%
# leo y convierto en DF el excel
datos_co2 = pd.read_excel(archivo)
datos_co2

# %% [markdown]
# Microsoft Excel es una de las herramientas de hojas de cálculo más utilizadas en el mundo, siendo ampliamente utilizada para almacenar y analizar datos en formato de tabla. En el video anterior, mostramos cómo la función read_excel se puede usar para leer un archivo de Excel en formato xlsx. Sin embargo, esta función es capaz de leer archivos en otros formatos, como: xls, xlsm, xlsb, odf, ods y odt.

# %%
datos_co2.head()

# %%
# con este comando pido que me muestre el nombre de las hojas
pd.ExcelFile(archivo).sheet_names

# %% [markdown]
# ###**Parámetros de la función read_excel**
# Documentación: https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html#pandas.read_excel

# %%
# Para ver las otras ojas utilizaremos la f(x) sheetname
emision_percapita = pd.read_excel(archivo, sheet_name='emisiones_percapita')
emision_percapita.tail() # muestra los 5 últimos registros
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
hoja_fuentes = pd.read_excel(archivo, sheet_name='fuentes')
hoja_fuentes.sample(8) # muestra 8 registros de forma aleatoria
# Out:
#                     País ISO 3166-1 alpha-3   Año       Total      Carbón  \
# 56926  Trinidad Y Tobago                TTO  1828      [NONE]      [NONE]
# 539              Albania                ALB  2017  CDIAC 2022  CDIAC 2022
# 31677              Libia                LBY  1875      [NONE]      [NONE]
# 12778    Costa De Marfil                CIV  2016  CDIAC 2022  CDIAC 2022
# 15920            Ecuador                ECU  1894      [NONE]      [NONE]
# 20013  Polinesio Francés                PYF  1907      [NONE]      [NONE]
# 59667           Tanzania                TZA  1849      [NONE]      [NONE]
# 32563         Luxemburgo                LUX  1945  CDIAC 2022  CDIAC 2022
#
#            Aceite         Gas        Cemento       Quema   Otros  \
# 56926      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# 539    CDIAC 2022  CDIAC 2022  Andrew cement        GGFR  [NONE]
# 31677      [NONE]      [NONE]         [NONE]      [NONE]  [NONE]
# ...

# %%
# leer el archivo excel (archivo) y la primera hoja del excel emisiones_C02, 4 columnas
intervalo = pd.read_excel(archivo, sheet_name='emisiones_C02',usecols= 'A:D') # solicita las primeras 4 columnas
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
# leer el archivo excel (archivo) y la primera hoja del excel emisiones_C02, 4 columnas y 8 filas
intervalo2 = pd.read_excel(archivo, sheet_name='emisiones_C02',usecols= 'A:D', nrows=8) # solicita las primeras 4 columnas
intervalo2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0

# %% [markdown]
# ###**Para exportar un DF a CSV, escribir un CSV**
# Documentación: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html#pandas.DataFrame.to_excel

# %%
intervalo.to_excel('emisiones2_co2.xlsx', index=False)

# %%
# para poder mantener este erchivo debo descargarlo, sino lo perderé
pd.read_excel('emisiones2_co2.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total
# 0      Afganistán                AFG  1750  0.000000e+00
# 1      Afganistán                AFG  1751  0.000000e+00
# 2      Afganistán                AFG  1752  0.000000e+00
# 3      Afganistán                AFG  1753  0.000000e+00
# 4      Afganistán                AFG  1754  0.000000e+00
# ...           ...                ...   ...           ...
# 63099      Global                WLD  2017  3.609674e+10
# 63100      Global                WLD  2018  3.682651e+10
# 63101      Global                WLD  2019  3.708256e+10
# 63102      Global                WLD  2020  3.526409e+10
# 63103      Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %% [markdown]
# ###**Leyendo datos de Google Sheet**
# link : https://docs.google.com/spreadsheets/d/1PQBGIFTz7zE75qpdW2zPMcE8L6NoNJGE7kcWihpGNmY/edit?usp=sharing

# %%
sheet_id ='1PQBGIFTz7zE75qpdW2zPMcE8L6NoNJGE7kcWihpGNmY'  # esto esta en el link después de la d/ hasta antes de /edit'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2_sheets = pd.read_csv(url)
datos_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %%
# para leer la 2da hoja
sheet_id ='1PQBGIFTz7zE75qpdW2zPMcE8L6NoNJGE7kcWihpGNmY'  # esto esta en el link después de la d/ hasta antes de /edit'
sheet_name = 'emisiones_percapita'
url_percapita= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheet = pd.read_csv(url_percapita)
percapita_sheet
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4,749,682  1,908,857  1,610,910
# 63100      Global                WLD  2018  4,792,753  1,919,213  1,596,350
# 63101      Global                WLD  2019  4,775,633  1,896,468  1,589,920
# 63102      Global                WLD  2020  4,497,423  1,807,760  1,427,353
# 63103      Global                WLD  2021  4,693,699  1,893,923  1,496,614
#
#              Gas  Cemento   Quema   Otros
# ...

# %%
sheet_id ='1PQBGIFTz7zE75qpdW2zPMcE8L6NoNJGE7kcWihpGNmY'  # esto esta en el link después de la d/ hasta antes de /edit'
sheet_name = 'fuentes'
url_fuentes= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fuentes_sheet = pd.read_csv(url_fuentes)
fuentes_sheet
# Out:
#              País ISO 3166-1 alpha-3   Año  \
# 0      Afganistán                AFG  1750
# 1      Afganistán                AFG  1751
# 2      Afganistán                AFG  1752
# 3      Afganistán                AFG  1753
# 4      Afganistán                AFG  1754
# ...           ...                ...   ...
# 63099      Global                WLD  2017
# 63100      Global                WLD  2018
# 63101      Global                WLD  2019
# 63102      Global                WLD  2020
# 63103      Global                WLD  2021
#
#                                       Total             Carbón  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

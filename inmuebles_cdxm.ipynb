# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliahfk/Data_science_Pandas/blob/main/inmuebles_cdxm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %% [markdown]
# ## **Biblioteca Pandas**

# %% [markdown]
# Pandas es una biblioteca de código abierto en Python utilizada para el análisis de datos. Proporciona herramientas poderosas y fáciles de usar para la manipulación y análisis de datos en formatos de tablas, como CSV, Excel, SQL y muchos otros.
#
# Con Pandas, podemos cargar datos desde diversas fuentes en un objeto llamado DataFrame, que es una tabla de datos similar a una hoja de cálculo de Excel. Luego, podemos trabajar con estos datos realizando operaciones como filtrar, ordenar, agregar y transformar.
#
# La biblioteca Pandas es ampliamente utilizada en aplicaciones de ciencia de datos, aprendizaje automático, finanzas y análisis empresarial. Es una herramienta esencial para profesionales que trabajan con datos, como analistas de datos, científicos de datos e ingenieros de datos.
#
# En resumen, la biblioteca Pandas es una herramienta de alto rendimiento para el análisis de datos en Python, que permite trabajar con datos en diferentes formatos y realizar diversas operaciones para manipular, analizar y visualizar los datos de manera eficiente y productiva.

# %% [markdown]
# Pandas ofrece diversas funciones para importar y exportar datos en diferentes formatos. Las principales funciones de Pandas para importar datos son las siguientes:
#
# **read_csv**(): Esta función se utiliza para leer archivos CSV (Comma Separated Values), que son archivos de texto que contienen datos separados por comas. Es posible proporcionar varios parámetros para personalizar la lectura del CSV, como el delimitador, el encabezado, el tipo de codificación, entre otros.
#
# **read_excel()**: Esta función se utiliza para leer archivos de Excel (.xls o .xlsx) y crear un DataFrame a partir de los datos.
#
# **read_json()**: Esta función se utiliza para leer archivos JSON (JavaScript Object Notation), que son archivos de texto que contienen datos en formato de objeto JavaScript.
#
# ** read_html()**: Esta función se utiliza para leer tablas HTML, que son estructuras de datos organizadas en formato de tabla en una página web.
#
# ** read_sql()**: Esta función se utiliza para leer datos de una base de datos relacional, como MySQL, PostgreSQL y SQL Server. Pandas es capaz de importar datos de diferentes maneras, lo que permite ajustar parámetros como la consulta, el nombre de la tabla y el tipo de datos de las columnas.
#
# Reiniciar sesión y ejecutar todo cuando se desconecta mi entorno de google colab.
#
# o ejecutar todas (las celdas)

# %% [markdown]
# una Serie es básicamente una matriz unidimensional etiquetada que puede almacenar cualquier tipo de datos. Cada elemento de la Serie está etiquetado con un índice que se puede utilizar para acceder y manipular sus valores.
#
# un DataFrame es básicamente una estructura de datos bidimensional que se utiliza para almacenar información estructurada en forma de tabla.Similar a una hoja de cálculo de Excel, con columnas etiquetadas y filas numeradas.

# %% [markdown]
# ## **Importando la Base de Datos**

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url, sep=';') # para leer la url ingresada anteriormente, normalmente la separación es por coma, pero cuando es ;
                          # o cualquier otro símbolo distinto debo poner sep
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 2           0   150  18200.0     14070.0    3888.5
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# ...       ...   ...      ...         ...       ...
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5
#
# [25121 rows x 9 columns]

# %%
datos = pd.read_csv(url, sep=';') # guardo la tabla en la variable datos
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 2           0   150  18200.0     14070.0    3888.5
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# ...       ...   ...      ...         ...       ...
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5
#
# [25121 rows x 9 columns]

# %%
datos.shape # Tabla datos contiene 25121 filas 9 columnas
# Out:
# (25121, 9)

# %%
datos.head() # muestra las primeras 5 filas
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail() # muestra las últimas 5 filas
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(8) # muestra la cantidad solicitada entre los paréntesis
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# 2   150   18200.0     14070.0    3888.5
# 3    15    2800.0      1365.0      70.0
# 4    48    2800.0       805.0       NaN
# 5   750   77000.0         NaN       NaN
# 6   695  122500.0     67175.5   10605.0
# 7    36    4200.0         NaN       NaN

# %%
datos.sample(10) # muestra una muestra de 10 filas aleatorias, no sólo las primeras o las últimas
# Out:
#                           Tipo             Colonia  Habitaciones  Garages  \
# 10814             Departamento             Condesa             3        0
# 4708   Conjunto Comercial/Sala            Santa Fe             0        1
# 7152              Departamento            Santa Fe             2        1
# 9595   Conjunto Comercial/Sala            Santa Fe             0        0
# 2554              Departamento  Villa de Guadalupe             2        1
# 23624             Departamento   Lomas de Padierna             2        0
# 2485   Conjunto Comercial/Sala    Centro Histórico             0        0
# 18619             Departamento            Santa Fe             2        1
# 3878              Departamento            Narvarte             2        0
# 19281  Conjunto Comercial/Sala            Santa Fe             0        1
#
#        Suites  Area   Valor  Condominio  Impuesto
# 10814       0   127  8750.0      4077.5       NaN
# 4708        0    33  4865.0      2450.0     350.0
# 7152        1    65  4550.0      3500.0       NaN
# 9595        0    42  7000.0      3150.0     420.0
# 2554        0    55  2800.0      1225.0      56.0
# 23624       0   199  4550.0         NaN       NaN
# 2485        0   135  8970.5      3899.0    1918.0
# 18619       1    90  6300.0      6118.0       NaN
# 3878        0    75  6300.0      1400.0       NaN
# 19281       0    36  4550.0      2492.0    4480.0

# %%
type(datos) # Que tipo de datos es// esto es un DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## ** Exploración de los datos**

# %%
datos.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 3220              Departamento         Arboledas             3        1
# 21788             Departamento              Roma             1        1
# 22628  Conjunto Comercial/Sala  Centro Histórico             0        0
# 14116             Departamento     Culhuacán CTM             2        0
# 22625    Departamento en Hotel              Roma             2        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 3220        1    60   5250.0      1771.0     133.0
# 21788       0    61   7700.0      2324.0      94.5
# 22628       0   219  80500.0     25347.0    4560.5
# 14116       0    54   2800.0       966.0       NaN
# 22625       2    92  14700.0      6650.0     805.0

# %%
datos.shape # tupla con las filas y las columnas que contiene el DataFrame
# Out:
# (25121, 9)

# %% [markdown]
# documentación Pandas
# https://pandas.pydata.org/docs/

# %%
datos.columns # me muestra un objeto con toda la información con los nombres de las columnas, las 9 columnas.
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info() # los datos de tipo object son str cadena de caracteres
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones', 'Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %%
datos[['Habitaciones', 'Valor']].head(10) # puedo utilizar ej: .head(x), head(), sample(), tail(5), tail(),etc
# Out:
#    Habitaciones     Valor
# 0             1    5950.0
# 1             2   24500.0
# 2             0   18200.0
# 3             1    2800.0
# 4             1    2800.0
# 5             5   77000.0
# 6             0  122500.0
# 7             1    4200.0
# 8             1    7000.0
# 9             1    6300.0

# %% [markdown]
# ## ** Análisis Exploratorio de Datos **

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos['Valor'].mean() # promedio de la columna Valor
# Out:
# np.float64(36885.05048392878)

# %% [markdown]
# ## método groupby

# %% [markdown]
# El método groupby de Pandas permite agrupar y resumir datos de un DataFrame basado en uno o más criterios. Estos criterios pueden ser variables numéricas o categóricas, como columnas o índices del DataFrame.
#
# La idea detrás de groupby es dividir los datos en grupos basados en los criterios seleccionados y luego aplicar una operación a estos grupos. Esta operación puede ser una función de agregación, como suma, promedio, recuento, desviación estándar, entre otras, o incluso una operación personalizada definida por el usuario.

# %% [markdown]
# Este método tiene varios parámetros, algunos de los cuales son:
#
# - by: Este es el parámetro más común y se utiliza para especificar la columna o columnas por las cuales queremos agrupar. Como argumento, podemos pasar el nombre de una columna o una lista de nombres de columnas.
#
# - axis: Utilizamos este parámetro para especificar el eje a lo largo del cual queremos agrupar. El valor predeterminado es 0, lo que significa que se agruparán las filas. Si deseamos agrupar las columnas, debemos establecer este parámetro en 1.
#
# - sort: Este parámetro es un booleano (True o False) que indica si los grupos deben ordenarse por el valor de la columna de agrupación. El valor predeterminado es True.
#
# - dropna: Utilizamos este parámetro para controlar si los valores faltantes (NaN) se eliminarán o no durante el proceso de agrupación. El valor predeterminado es True.

# %% [markdown]
# Veamos un ejemplo simple utilizando groupby. Supongamos que tenemos el siguiente DataFrame:
#
# Código del DataFrame:

# %%
import pandas as pd

df = pd.DataFrame({
   'Animal': ['Perro', 'Gato', 'Elefante', 'Perro', 'Gato', 'Elefante'],
   'Color': ['Negro', 'Blanco', 'Gris', 'Marrón', 'Negro', 'Marrón'],
   'Cantidad': [2, 3, 1, 4, 2, 2]
})
df
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %% [markdown]
# Aquí tenemos un DataFrame con datos sobre algunos animales. Usaremos groupby para agrupar los datos por tipo de animal y realizar la suma de la columna "Cantidad" para obtener el total de cada tipo de animal:

# %%
df.groupby('Animal')['Cantidad'].sum()
# Out:
# Animal
# Elefante    3
# Gato        5
# Perro       6
# Name: Cantidad, dtype: int64

# %%
df.groupby(['Animal', 'Color'])[['Cantidad']].sum()
# Out:
#                  Cantidad
# Animal   Color
# Elefante Gris           1
#          Marrón         2
# Gato     Blanco         3
#          Negro          2
# Perro    Marrón         4
#          Negro          2

# %% [markdown]
# Pandas GroupBy: Su guía para agrupar datos en Python;
# https://realpython.com/pandas-groupby/
#
# Explicación detallada del groupby de Pandas.
# https://towardsdatascience.com/pandas-groupby-aggregate-transform-filter-c95ba3444bbb

# %% [markdown]
# Este comando arroja el promedio de todo

# %%
datos.groupby('Tipo').mean(numeric_only=True) # promedio de todas las columnas por el tipo
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# Galpón/Depósito/Almacén         0.069204   5.311419   0.000000   2660.487889
# Hotel                          25.500000   2.500000  12.000000    885.500000
# Industria                       0.000000   0.000000   0.000000     22.000000
# Loft                            1.078947   0.552632   0.421053     56.263158
# Loteo/Condominio                0.000000   0.000000   0.000000    215.000000
# Posada/Chalé                   23.000000   0.000000  23.000000    862.000000
# Rancho                          5.125000   0.000000   3.750000  14993.750000
# Terreno Estándar                0.066667   0.000000   0.000000   4012.044444
# Tienda en Centro Comercial      0.055838   8.385787   0.010152     92.197970
# Tienda/Salón                    0.011840   1.349727   0.001821    242.169399
#
#                                     Valor     Condominio      Impuesto
# Tipo
# Casa                         31453.177064    3699.421642   6629.404851
# Casa Comercial               54735.841584    7622.192308   6166.063380
# Casa de Condominio           51428.609836    5286.578804  15046.939394
# Casa de Vecindad              5961.740506     413.444444    706.850000
# Cochera/Estacionamiento       6995.454545    1069.075000    449.458333
# Cocineta                      4425.856061    1521.734214    280.701461
# Conjunto Comercial/Sala      57675.214550   17489.361142   5425.980245
# Departamento                 18683.269431    6797.092951   2634.921081
# Departamento en Hotel        16285.430769    7250.650602   1768.923885
# Edificio Completo           409418.080645  234304.608696  50413.735294
# Estudio                       8400.000000    1921.500000    529.375000
# Galpón/Depósito/Almacén     299984.140138   48581.166667  22260.530899
# Hotel                        87500.000000            NaN  21707.000000
# Industria                   420000.000000            NaN           NaN
# Loft                          9924.526316    3501.200000    887.080645
# Loteo/Condominio             92166.666667            NaN  17097.500000
# Posada/Chalé                  5180.000000    1032.500000           NaN
# Rancho                       38014.375000            NaN   4375.000000
# Terreno Estándar            135364.444444            NaN  24988.750000
# Tienda en Centro Comercial   32556.785714    6824.166667   4127.755882
# Tienda/Salón                 56263.544252   10395.491137  10532.468927

# %% [markdown]
# ## **¿Cuáles son los valores promedio de alquiler por tipo de propiedad?**

# %%
# ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?
datos.groupby('Tipo')['Valor'].mean() # promedio de la columna Valor por Tipo
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# Name: Valor, dtype: float64

# %%
datos.groupby('Tipo')['Valor'].mean().sort_values(ascending=True) # ordena de mayor a menor
# Out:
# Tipo
# Cocineta                        4425.856061
# Posada/Chalé                    5180.000000
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Estudio                         8400.000000
# Loft                            9924.526316
# Departamento en Hotel          16285.430769
# Departamento                   18683.269431
# Casa                           31453.177064
# Tienda en Centro Comercial     32556.785714
# Rancho                         38014.375000
# Casa de Condominio             51428.609836
# Casa Comercial                 54735.841584
# Tienda/Salón                   56263.544252
# Conjunto Comercial/Sala        57675.214550
# Hotel                          87500.000000
# Loteo/Condominio               92166.666667
# Terreno Estándar              135364.444444
# Galpón/Depósito/Almacén       299984.140138
# Edificio Completo             409418.080645
# Industria                     420000.000000
# Name: Valor, dtype: float64

# %%
# Agrupo por el promedio de cada Tipo en forma ascendente (más caro a lo mas barato)
# aquí me muestra todos los datos, los comerciales y los recidenciales
df_tipo_valor = datos.groupby('Tipo')['Valor'].mean().sort_values(ascending=True)
df_tipo_valor.plot(kind='barh', title='Promedio de Alquiler por Tipo', figsize=(10,5), color = 'purple')
# Out:
# <Axes: title={'center': 'Promedio de Alquiler por Tipo'}, ylabel='Tipo'>

# %% [markdown]
# ## **¿Cuáles son los valores promedio de alquiler por tipo de propiedad?, especificamente las propiedades residenciales**

# %%
datos.Tipo.unique() # me muestra los valores únicos de la columna Tipo
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
# agrupe todos los inmuebles comerciales en una variable
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón','Casa Comercial',
                         'Terreno Estándar', 'Cochera/Estacionamiento','Galpón/Depósito/Almacén',
                         'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio','Industria']

# %%
# para hacer una consulta a una variable y recorrerla // aquí me mostrara la cantidad de filas con los inmuebles comerciales
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# 2           0   150   18200.0     14070.0    3888.5
# 6           0   695  122500.0     67175.5   10605.0
# 11          0   536   98000.0         NaN   12470.5
# 24          0    22    2450.0         NaN       NaN
# 26          0  1306  411390.0     68201.0       NaN
# ...       ...   ...       ...         ...       ...
# 25107       0    55    7000.0      3836.0       NaN
# 25110       0   140   14000.0      4942.0    1736.0
# 25112       0    32    2100.0      3622.5     290.5
# 25116       0   755   49000.0         NaN       NaN
# 25120       0   250   22750.0     14721.0    3881.5
#
# [7812 rows x 9 columns]

# %%
#para hacer una consulta a una variable y recorrerla // aquí me mostrara la cantidad de filas con los inmuebles no comerciales.
datos.query('@inmuebles_comerciales not in Tipo') # al consultar por inmuebles_comerciales not in Tipo me muestra lo contario, los residenciales.
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# 5           5   750  77000.0         NaN       NaN
# ...       ...   ...      ...         ...       ...
# 25114       0    28   3500.0      1260.0      87.5
# 25115       4   450  52500.0      5988.5    8162.0
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
#
# [17309 rows x 9 columns]

# %%
df_residencial = datos.query('@inmuebles_comerciales not in Tipo')
df_residencial
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# 1           1   100  24500.0         NaN       NaN
# 3           0    15   2800.0      1365.0      70.0
# 4           0    48   2800.0       805.0       NaN
# 5           5   750  77000.0         NaN       NaN
# ...       ...   ...      ...         ...       ...
# 25114       0    28   3500.0      1260.0      87.5
# 25115       4   450  52500.0      5988.5    8162.0
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
#
# [17309 rows x 9 columns]

# %%
df_tipo_valor_residencial = df_residencial.groupby('Tipo')['Valor'].mean().sort_values(ascending=True)
df_tipo_valor_residencial.plot(kind='barh', title='Promedio de Alquiler por Tipo', figsize=(10,5), color = 'purple')
# Out:
# <Axes: title={'center': 'Promedio de Alquiler por Tipo'}, ylabel='Tipo'>

# %% [markdown]
# ## Query

# %% [markdown]
# El método query es una herramienta de Pandas que permite seleccionar datos en un DataFrame utilizando las condiciones que especificamos. Utiliza una sintaxis similar a SQL y es útil cuando necesitamos filtrar nuestros datos.

# %% [markdown]
# ## **¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?**

# %%
df_residencial.Tipo.unique() # muestra valores únicos (sin duplicados) de un array
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df_residencial.Tipo.value_counts() # se usa para contar la frecuencia (número de apariciones) de cada valor único en una serie o columna
                                   # de un DataFrame. Por defecto lo muestra descendente
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df_residencial.Tipo.value_counts(normalize=True) # me muestra el % por cada tipo
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
# Gráficar
porcentaje_tipo = df_residencial.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind='bar', title='Porcentaje de Tipo', figsize=(10,5), color = 'green', xlabel='Tipos', ylabel='Porcentaje')
# Out:
# <Axes: title={'center': 'Porcentaje de Tipo'}, xlabel='Tipos', ylabel='Porcentaje'>

# %% [markdown]
# Enfocarse en el inmueble con mayor porcentaje para continuar

# %%
df_depto1 = df_residencial.query('Tipo == "Departamento"')
df_depto1.head(4)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
# 7  Departamento  Centro Histórico             1        0       0    36
# 8  Departamento           Condesa             1        0       1    40
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN
# 7  4200.0         NaN       NaN
# 8  7000.0      1963.5     175.0

# %%
df_depto1.shape # nuevo DataFrame solo con los departamentos, arroja 14764 filas y 9 columnas
# Out:
# (14764, 9)

# %% [markdown]
# Cuando trabajamos con bases de datos, en ocasiones puede ser necesario cambiar los nombres de las columnas. Por ejemplo, cuando creamos el siguiente DataFrame en nuestro proyecto:

# %%
df_residencial['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
# Out:
#                        proportion
# Tipo
# Casa                     0.031487
# Casa de Condominio       0.035242
# Casa de Vecindad         0.009128
# Cocineta                 0.041943
# Departamento             0.852967
# Departamento en Hotel    0.026287
# Estudio                  0.000231
# Loft                     0.002195
# Posada/Chalé             0.000058
# Rancho                   0.000462

# %% [markdown]
# Podemos ver que la columna con los porcentajes está nombrada como "Tipo". ¿Y si quisiéramos cambiar su nombre a "Porcentajes"?
#
# En ese caso, podemos utilizar el método rename() para cambiar el nombre de esa columna. Este método nos permite especificar un diccionario que asocia el nombre antiguo de la columna con el nuevo nombre que deseamos asignar.

# %%
# Guardando el DataFrame en una variable
df_ejemplo = df_residencial['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')

# Cambiando el nombre de la columna "proportion" a "Porcentajes"
df_ejemplo.rename(columns={'proportion': 'Porcentajes'}, inplace=True)

# Visualizando el DataFrame
df_ejemplo
# Out:
#                        Porcentajes
# Tipo
# Casa                      0.031487
# Casa de Condominio        0.035242
# Casa de Vecindad          0.009128
# Cocineta                  0.041943
# Departamento              0.852967
# Departamento en Hotel     0.026287
# Estudio                   0.000231
# Loft                      0.002195
# Posada/Chalé              0.000058
# Rancho                    0.000462

# %% [markdown]
# El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:
#
# - Calcular el promedio de habitaciones por departamento.
# - Verificar cuántas colonias únicas existen en nuestra base de datos.
#  -Analizar qué colonias tienen el promedio de alquiler más alto.
# - Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

# %%
# Calcular el promedio de habitaciones por departamento.
df_depto1['Habitaciones'].mean()
# Out:
# np.float64(2.5041994039555675)

# %%
# Verificar cuántas colonias únicas existen en nuestra base de datos.
# Analizar qué colonias tienen el promedio de alquiler más alto.
df_depto1['Colonia'].unique()
# Out:
# array(['Centro Histórico', 'Del Valle', 'Condesa', 'Santa Fe', 'Narvarte',
#        'Coyoacán', 'Roma', 'Lomas de Chapultepec',
#        'San Pedro de los Pinos', 'Polanco', 'San Ángel', 'San Jerónimo',
#        'Ciudad de los Deportes', 'Bosques de las Lomas', 'Juárez',
#        'Chapultepec', 'San Miguel Chapultepec', 'El Rosedal',
#        'Nueva Santa María', 'Arboledas', 'Villa de Cortés', 'Casa Blanca',
#        'Álvaro Obregón', 'Iztacalco', 'Mixcoac', 'Peralvillo', 'Napoles',
#        'Nativitas', 'Tlalpan', 'Roma Norte', 'San Rafael',
#        'Industrial Vallejo', 'La Condesa', 'Iztapalapa', 'Villa Coapa',
#        'Villa de Guadalupe', 'Lomas de Padierna', 'El Contadero',
#        'Las Águilas', 'Culhuacán CTM', 'El Arenal', 'San Sebastián',
#        'San Andrés Tetepilco', 'Loma Bonita', 'Santa Cruz Atoyac',
#        'El Rodeo', 'La Virgen', 'Lindavista', 'San José Insurgentes',
#        'Moctezuma', 'Atlampa', 'Del Valle Centro', 'Lindavista Sur',
#        'Potrero de San Bernardino', 'Doctores', 'Barrio Bravo', 'La Loma',
#        'Residencial Emiliano Zapata', 'La Florida',
#        'Santa Marta Acatitla', 'San Antonio Tecomitl', 'Vallejo',
#        'San Juan Xalpa', 'Los Alpes', 'Santa María Aztahuacán',
#        'Bosques de Aragón', 'Los Reyes Coyoacán', 'Zacatenco',
#        'San Felipe de Jesús', 'La Merced', 'Ajusco', 'Roma Sur',
#        'Tepalcatlalpan', 'Tláhuac', 'Jardines de San Mateo',
#        'San Gregorio Atlapulco', 'Santa María Nonoalco', 'Tlalnepantla',
#        'Pueblo Culhuacán', 'Reforma Política', 'Atlalilco',
#        'Santa María Nativitas', 'Pedregal'], dtype=object)

# %%
# Muuestra el total de las colonias unicas
len(df_depto1['Colonia'].unique())
# Out:
# 83

# %%
alquiler_por_colonia = df_depto1.groupby('Colonia')['Valor'].mean().sort_values(ascending=False)
# El parámetro ascending=False se utiliza en la función sort_values() para ordenar los valores en orden descendente (de mayor a menor).
alquiler_por_colonia
# Out:
# Colonia
# Los Alpes                    54250.000000
# Bosques de Aragón            35948.718750
# Coyoacán                     33205.218609
# Roma                         32530.388539
# Lomas de Chapultepec         30232.165189
#                                  ...
# El Rodeo                      2275.000000
# Tláhuac                       2275.000000
# San Antonio Tecomitl          2065.000000
# Santa María Aztahuacán        1785.000000
# Potrero de San Bernardino     1190.000000
# Name: Valor, Length: 83, dtype: float64

# %%
# Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.
alquiler_por_colonia.head(5).plot(kind='barh', title='Promedio de Alquiler por Colonia', figsize=(10,5), color = 'darkblue', xlabel='Promedio Alquiler', ylabel='Colonia')
# Out:
# <Axes: title={'center': 'Promedio de Alquiler por Colonia'}, xlabel='Promedio Alquiler', ylabel='Colonia'>

# %% [markdown]
# ## **Tratamiento Datos Nulos**

# %%
df_depto1.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# 10          False     False
# ...           ...       ...
# 25111       False     False
# 25113       False     False
# 25114       False     False
# 25118       False     False
# 25119       False      True
#
# [14764 rows x 9 columns]

# %%
# Verificar la existencia de datos nulos
df_depto1.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %% [markdown]
# En este caso los datos nulos se les asignara el valor 0

# %%
df_depto = df_depto1.fillna(0) # comando fillna () reemplaza el valor
df_depto.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# Tratar datos nulos en una base de datos es muy importante porque estos datos faltantes pueden interferir directamente en la calidad de los análisis y los resultados obtenidos. Cuando hay datos nulos en un conjunto de datos, pueden surgir problemas como sesgo, reducción de la precisión y falta de precisión en la información obtenida.
#
# Existen varias formas de tratar datos nulos con Pandas. Algunas de las formas principales son:
#
# - **Eliminar los datos nulos**: Es posible eliminar las filas o columnas que contienen valores nulos utilizando el método dropna(). Este método elimina todas las filas o columnas que tienen al menos un valor nulo.
#
# - **Llenar los datos nulos**: Utilizando el método fillna(), podemos llenar los valores nulos con un valor específico. Además, también es posible utilizar argumentos específicos del método fillna(), como method="ffill" o method="bfill", para llenar los valores nulos con el valor anterior o posterior, respectivamente.
#
# - **Interpolar los datos nulos**: Es posible utilizar el método interpolate() para llenar los valores nulos con valores interpolados, es decir, valores calculados a partir de los valores vecinos.
#
# Es importante elegir la mejor forma de tratar los datos nulos según la situación específica y el objetivo del análisis de datos.

# %% [markdown]
# ## **Remover Registros Inconsistentes**

# %%
# aquí consulto con query que me muestra todos los deptos con valor 0 o Condominio con valor 0 // Indica 500 filas
df_depto.query('Valor == 0 | Condominio == 0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# 7        36   4200.0         0.0       0.0
# 49       70      0.0      3395.0     238.0
# 74       80   3500.0         0.0       0.0
# 116      50   3850.0         0.0       0.0
# 136      65   8225.0         0.0       0.0
# ...     ...      ...         ...       ...
# 24721    43   3150.0         0.0      56.0
# 24736    30   9100.0         0.0       0.0
# 24866   130  16100.0         0.0       0.0
# 24892    40   1925.0         0.0       0.0
# 25014    70   4200.0         0.0       0.0
#
# [500 rows x 9 columns]

# %%
# aquí muestra los indices de los datos con 0
df_depto.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
# axis = 0 me refiero a las filas
df_depto_sin_nulos =df_depto.drop(df_depto.query('Valor == 0 | Condominio == 0').index, axis=0)
df_depto_sin_nulos
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# 13     Departamento              Santa Fe             2        1       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# 4        48   2800.0       805.0       0.0
# 8        40   7000.0      1963.5     175.0
# 10      243  45500.0      7000.0    2810.5
# 13       67   5950.0      2061.5     514.5
# ...     ...      ...         ...       ...
# 25111    80  10500.0      3535.0     871.5
# 25113   150  52500.0      4900.0    2100.0
# 25114    28   3500.0      1260.0      87.5
# 25118    48   4900.0      1781.5     129.5
# 25119    70  10500.0      2660.0       0.0
#
# [14264 rows x 9 columns]

# %%
# Otra forma
df_remover = df_depto.query('Valor == 0 | Condominio == 0').index

# %%
df_depto.drop(df_remover, axis=0, inplace=True)
df_depto
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# 13     Departamento              Santa Fe             2        1       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# 4        48   2800.0       805.0       0.0
# 8        40   7000.0      1963.5     175.0
# 10      243  45500.0      7000.0    2810.5
# 13       67   5950.0      2061.5     514.5
# ...     ...      ...         ...       ...
# 25111    80  10500.0      3535.0     871.5
# 25113   150  52500.0      4900.0    2100.0
# 25114    28   3500.0      1260.0      87.5
# 25118    48   4900.0      1781.5     129.5
# 25119    70  10500.0      2660.0       0.0
#
# [14264 rows x 9 columns]

# %%
df_depto.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
# 13  Departamento          Santa Fe             2        1       1    67
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       0.0
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5
# 13   5950.0      2061.5     514.5

# %%
df_depto.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %%
df_depto.Tipo.unique() # muestra que solo en tipo hay departamentos
# Out:
# array(['Departamento'], dtype=object)

# %%
# aquí elimino la columna tipo
df_depto.drop('Tipo', axis=1, inplace=True)
df_depto.sample(10)
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 24575              Santa Fe             2        2       1   119  15750.0
# 5060                Condesa             2        0       0    62   5600.0
# 8837               Narvarte             3        1       0   107   7700.0
# 23527              Narvarte             2        1       0    84   6475.0
# 94     Lomas de Chapultepec             3        1       0    85  13650.0
# 15615              Narvarte             2        1       0    56   4900.0
# 24588            San Rafael             2        1       0    70   5950.0
# 4042              La Merced             2        0       0    35   2975.0
# 23238              Santa Fe             3        2       3   142  16100.0
# 10368              Santa Fe             3        2       1   130  11200.0
#
#        Condominio  Impuesto
# 24575      6475.0    2030.0
# 5060       4200.0     105.0
# 8837       2100.0     504.0
# 23527      3290.0     665.0
# 94         2800.0    4238.5
# 15615      2775.5     168.0
# 24588      3500.0       0.0
# 4042        315.0       0.0
# 23238      5733.0    1396.5
# 10368      4200.0       0.0

# %%
df_depto.shape
# Out:
# (14264, 8)
